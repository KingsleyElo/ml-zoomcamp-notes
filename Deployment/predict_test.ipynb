# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
import requests

# %%
url = 'http://localhost:9696/predict'

# %%
customer = {
  "tenure": 30,
  "monthlycharges": 79.85,
  "totalcharges": 3320.75,
  "gender": 'female',
  "seniorcitizen": 0,
  "partner": "no",
  "dependents": "no",
  "phoneservice": "yes",
  "multiplelines": "no",
  "internetservice": "dsl",
  "onlinesecurity": "yes",
  "onlinebackup": "no",
  "deviceprotection": "yes",
  "techsupport": "yes",
  "streamingtv": "yes",
  "streamingmovies": "yes",
  "contract": "one_year",
  "paperlessbilling": "yes",
  "paymentmethod": "bank_transfer_(automatic)"
}

# %%
response = requests.post(url, json=customer).json()
print(response)

if response['churn'] == True:
    print(f'sending promo email to customer')
else:
    print('not sending promo email to customer')
# Out:
# {'churn': False, 'churn_probability': 0.12539310961870584}
# not sending promo email to customer

# %% [markdown]
# to deploy use the below
#
# ```bash
# waitress-serve --listen=0.0.0.0:9696 predict:app
# ```
